# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import tensorflow as tf
import numpy as np
import tflearn as tflearn

# %%
df = pd.read_csv('train.csv')
sns.pairplot(df.dropna(), hue="Survived", size=2, diag_kind="kde")
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-53-05f9b75c857d> in <module>()
#       1 df = pd.read_csv('train.csv')
# ----> 2 sns.pairplot(df.dropna(), hue="Survived", size=2, diag_kind="kde")
#
# ~/.brew/lib/python3.6/site-packages/seaborn/linearmodels.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1610         elif diag_kind == "kde":
#    1611             diag_kws["legend"] = False
# -> 1612             grid.map_diag(kdeplot, **diag_kws)
#    1613
#    1614     # Maybe plot on the off-diagonals
#
# ~/.brew/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1356                     plt.sca(ax)
#    1357                     func(data_k, label=label_k,
# -> 1358                          color=self.palette[k], **kwargs)
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df.isnull().sum()

# %%
df.columns

# %%
df = df.drop(df.columns[[0, 1, 3, 8, 10]], axis=1)

# %%
df.replace(['male', 'female'], [1, 2], inplace=True)
df['Embarked'].unique()

# %%
df.replace(['S', 'C', 'Q', np.nan], [1, 2, 3, 0], inplace=True)
df['Embarked'].unique()

# %%
df.isnull().values.any()
