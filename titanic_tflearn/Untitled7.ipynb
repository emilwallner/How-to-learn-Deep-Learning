# %%
import tflearn as tf
import numpy as np

# %%
data, labels = tf.data_utils.load_csv('train.csv', target_column=1, columns_to_ignore=[0, 3, 8, 10])

# %%
data
# Out:
# [['3', 'male', '22', '1', '0', '7.25', 'S'],
#  ['1', 'female', '38', '1', '0', '71.2833', 'C'],
#  ['3', 'female', '26', '0', '0', '7.925', 'S'],
#  ['1', 'female', '35', '1', '0', '53.1', 'S'],
#  ['3', 'male', '35', '0', '0', '8.05', 'S'],
#  ['3', 'male', '', '0', '0', '8.4583', 'Q'],
#  ['1', 'male', '54', '0', '0', '51.8625', 'S'],
#  ['3', 'male', '2', '3', '1', '21.075', 'S'],
#  ['3', 'female', '27', '0', '2', '11.1333', 'S'],
#  ['2', 'female', '14', '1', '0', '30.0708', 'C'],
#  ['3', 'female', '4', '1', '1', '16.7', 'S'],
#  ['1', 'female', '58', '0', '0', '26.55', 'S'],
#  ['3', 'male', '20', '0', '0', '8.05', 'S'],
#  ['3', 'male', '39', '1', '5', '31.275', 'S'],
#  ['3', 'female', '14', '0', '0', '7.8542', 'S'],
#  ['2', 'female', '55', '0', '0', '16', 'S'],
#  ['3', 'male', '2', '4', '1', '29.125', 'Q'],
#  ['2', 'male', '', '0', '0', '13', 'S'],
#  ['3', 'female', '31', '1', '0', '18', 'S'],
#  ['3', 'female', '', '0', '0', '7.225', 'C'],
# ...

# %%
for x in data:
    for i in range(len(x)):
        if x[i] == '':
            print(x)
            x[i] = 0
# Out:
# ['3', 'male', '', '0', '0', '8.4583', 'Q']
# ['2', 'male', '', '0', '0', '13', 'S']
# ['3', 'female', '', '0', '0', '7.225', 'C']
# ['3', 'male', '', '0', '0', '7.225', 'C']
# ['3', 'female', '', '0', '0', '7.8792', 'Q']
# ['3', 'male', '', '0', '0', '7.8958', 'S']
# ['1', 'female', '', '1', '0', '146.5208', 'C']
# ['3', 'female', '', '0', '0', '7.75', 'Q']
# ['3', 'male', '', '0', '0', '7.2292', 'C']
# ['3', 'male', '', '0', '0', '7.8958', 'C']
# ['3', 'male', '', '0', '0', '8.05', 'S']
# ['3', 'male', '', '1', '0', '15.5', 'Q']
# ['3', 'female', '', '0', '0', '7.75', 'Q']
# ['3', 'male', '', '2', '0', '21.6792', 'C']
# ['1', 'male', '', '0', '0', '35.5', 'S']
# ['1', 'female', '38', '0', '0', '80', '']
# ['1', 'male', '', '0', '0', '27.7208', 'C']
# ['3', 'male', '', '1', '1', '15.2458', 'C']
# ['3', 'male', '', '0', '0', '7.8958', 'S']
# ['3', 'male', '', '0', '0', '8.05', 'S']
# ['3', 'female', '', '0', '0', '7.7875', 'Q']
# ['3', 'male', '', '0', '0', '8.05', 'S']
# ...
